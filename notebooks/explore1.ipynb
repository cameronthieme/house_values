# %% [markdown]
# # House Prices Initial Exploration

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Read Data

# %%
df_train = pd.read_csv('../data/raw/train.csv')

# %% [markdown]
# ## Explore Data

# %%
df_train.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# ...

# %%
df_train.describe()
# this command gives us stats for numerical data
# notice that around half variables here are numerical (38/81)
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
# change number of rows/columns we will view
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# %%
# count number of non-empty entries in each column
df_train.count()
# Out:
# Id               1460
# MSSubClass       1460
# MSZoning         1460
# LotFrontage      1201
# LotArea          1460
# Street           1460
# Alley              91
# LotShape         1460
# LandContour      1460
# Utilities        1460
# LotConfig        1460
# LandSlope        1460
# Neighborhood     1460
# Condition1       1460
# Condition2       1460
# BldgType         1460
# HouseStyle       1460
# OverallQual      1460
# OverallCond      1460
# YearBuilt        1460
# YearRemodAdd     1460
# RoofStyle        1460
# RoofMatl         1460
# Exterior1st      1460
# Exterior2nd      1460
# MasVnrType        588
# MasVnrArea       1452
# ExterQual        1460
# ExterCond        1460
# Foundation       1460
# BsmtQual         1423
# BsmtCond         1423
# BsmtExposure     1422
# BsmtFinType1     1423
# BsmtFinSF1       1460
# BsmtFinType2     1422
# BsmtFinSF2       1460
# BsmtUnfSF        1460
# TotalBsmtSF      1460
# Heating          1460
# HeatingQC        1460
# ...

# %%
# verify that count and na add up to 1460 in all cases

# create df that is merger of two series: the count and na series of df_train
df_temp = pd.merge(df_train.count().to_frame(), df_train.isna().sum().to_frame(), left_index = True, right_index = True)

# print said df
print(df_temp)

# instead of checking the whole printout, double check that only 1460 exists as a value when summing those two columns
(df_temp['0_x'] + df_temp['0_y']).value_counts()
# Out:
#                 0_x  0_y
# Id             1460    0
# MSSubClass     1460    0
# MSZoning       1460    0
# LotFrontage    1201  259
# LotArea        1460    0
# ...             ...  ...
# MoSold         1460    0
# YrSold         1460    0
# SaleType       1460    0
# SaleCondition  1460    0
# SalePrice      1460    0
#
# [81 rows x 2 columns]
# 1460    81
# Name: count, dtype: int64

# %%
# Explore the Heating variable
df_train.Heating.value_counts()
# Out:
# Heating
# GasA     1428
# GasW       18
# Grav        7
# Wall        4
# OthW        2
# Floor       1
# Name: count, dtype: int64

# %%
sns.histplot(data = df_train, x = 'Heating')
# Out:
# <Axes: xlabel='Heating', ylabel='Count'>

# %%
df_train.Alley.value_counts()
# Out:
# Alley
# Grvl    50
# Pave    41
# Name: count, dtype: int64

# %%
sns.scatterplot(data = df_train, x = 'OverallCond', y = 'SalePrice', alpha = 0.25)
# Out:
# <Axes: xlabel='OverallCond', ylabel='SalePrice'>

# %%
# more scatterplots
cols = ['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea']
sns.set(style = 'ticks')
sns.pairplot(df_train[cols], height=2)
plt.show()

# %% [markdown]
# ## Pearson CC

# %%
# obtain all numeric values of df (where Pearson is defined)
df_train_numeric = df_train.select_dtypes(include='number')

# find the correlation matrix; this is a df
# then I take only the column of interest; result is Series
sale_corr = df_train_numeric.corr()['SalePrice']

# sort that series
sale_corr = sale_corr.sort_values(ascending = False)

# %%
sale_corr
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
#                    ...
# YrSold          -0.028923
# OverallCond     -0.077856
# MSSubClass      -0.084284
# EnclosedPorch   -0.128578
# KitchenAbvGr    -0.135907
# Name: SalePrice, Length: 38, dtype: float64

# %% [markdown]
# Surprising that overall condition has a slightly negative correlation

# %% [markdown]
# ## Going Log
#
# Since the goal is to predict the log of sales price, let's convert that right away

# %%
df_train['SalePrice']
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
df_train['LogSalePrice']= np.log(df_train['SalePrice'])

# %%
df_train['LogSalePrice']
# Out:
# 0       12.247694
# 1       12.109011
# 2       12.317167
# 3       11.849398
# 4       12.429216
#           ...
# 1455    12.072541
# 1456    12.254863
# 1457    12.493130
# 1458    11.864462
# 1459    11.901583
# Name: LogSalePrice, Length: 1460, dtype: float64

# %%
sns.histplot(data = df_train, x = 'LogSalePrice')
# Out:
# <Axes: xlabel='LogSalePrice', ylabel='Count'>

# %%
sns.histplot(data = df_train, x = 'SalePrice')
# Out:
# <Axes: xlabel='SalePrice', ylabel='Count'>

# %% [markdown]
# ## Redo Pearson
#
# Now that we are in log

# %%
# obtain all numeric values of df (where Pearson is defined)
df_train_numeric = df_train.select_dtypes(include='number')

# find the correlation matrix; this is a df
# then I take only the column of interest; result is Series
sale_corr = df_train_numeric.corr()['SalePrice']

# sort that series
sale_corr = sale_corr.sort_values(ascending = False)

# %%
sale_corr
# Out:
# SalePrice        1.000000
# OverallQual      0.817184
# GrLivArea        0.700927
# GarageCars       0.680625
# GarageArea       0.650888
# TotalBsmtSF      0.612134
# 1stFlrSF         0.596981
# FullBath         0.594771
# YearBuilt        0.586570
# YearRemodAdd     0.565608
# GarageYrBlt      0.541073
# TotRmsAbvGrd     0.534422
# Fireplaces       0.489449
# MasVnrArea       0.430809
# BsmtFinSF1       0.372023
# LotFrontage      0.355878
# WoodDeckSF       0.334135
# OpenPorchSF      0.321053
# 2ndFlrSF         0.319300
# HalfBath         0.313982
# LotArea          0.257320
# BsmtFullBath     0.236224
# BsmtUnfSF        0.221985
# BedroomAbvGr     0.209044
# ScreenPorch      0.121208
# PoolArea         0.069798
# MoSold           0.057329
# 3SsnPorch        0.054900
# BsmtFinSF2       0.004832
# BsmtHalfBath    -0.005149
# Id              -0.017942
# MiscVal         -0.020021
# OverallCond     -0.036868
# YrSold          -0.037263
# LowQualFinSF    -0.037963
# ...

# %% [markdown]
# ## More numberic values
#
# Let's convert any binary things to numeric

# %%
# first get a sense of all of the variables and how many are categorical
df_train.nunique()
# Out:
# Id               1460
# MSSubClass         15
# MSZoning            5
# LotFrontage       110
# LotArea          1073
# Street              2
# Alley               2
# LotShape            4
# LandContour         4
# Utilities           2
# LotConfig           5
# LandSlope           3
# Neighborhood       25
# Condition1          9
# Condition2          8
# BldgType            5
# HouseStyle          8
# OverallQual        10
# OverallCond         9
# YearBuilt         112
# YearRemodAdd       61
# RoofStyle           6
# RoofMatl            8
# Exterior1st        15
# Exterior2nd        16
# MasVnrType          3
# MasVnrArea        327
# ExterQual           4
# ExterCond           5
# Foundation          6
# BsmtQual            4
# BsmtCond            4
# BsmtExposure        4
# BsmtFinType1        6
# BsmtFinSF1        637
# BsmtFinType2        6
# BsmtFinSF2        144
# BsmtUnfSF         780
# TotalBsmtSF       721
# Heating             6
# HeatingQC           5
# ...

# %%
# which columns are binarizable?

for column in df_train.columns:
    unique_count = df_train[column].nunique()
    if unique_count == 2:
        unique_values = df_train[column].unique()
        print(f"Column '{column}' has exactly 2 unique values: {unique_values}")
# Out:
# Column 'Street' has exactly 2 unique values: ['Pave' 'Grvl']
# Column 'Alley' has exactly 2 unique values: [nan 'Grvl' 'Pave']
# Column 'Utilities' has exactly 2 unique values: ['AllPub' 'NoSeWa']
# Column 'CentralAir' has exactly 2 unique values: ['Y' 'N']

# %% [markdown]
# Based on above, 'Alley' isn't actually binary.  It seems that nan values show up for houses without an alley.  I also want to map to binary in a way that preserves their obvious meaning.

# %%
binary_columns = ['Street', 'Utilities', 'CentralAir']
for column in binary_columns:
    unique_values = df_train[column].unique()
    # defining binary map a little weird since 'Y' was first, 'N' second
    binary_mapping = {unique_values[0]: 1, unique_values[1]:0}
    df_train[column] = df_train[column].map(binary_mapping)

# %% [markdown]
# ## Pearson Again

# %%
# obtain all numeric values of df (where Pearson is defined)
df_train_numeric = df_train.select_dtypes(include='number')

# find the correlation matrix; this is a df
# then I take only the column of interest; result is Series
sale_corr = df_train_numeric.corr()['SalePrice']

# sort that series
sale_corr = sale_corr.sort_values(ascending = False)

print(sale_corr)
# Out:
# SalePrice        1.000000
# OverallQual      0.817184
# GrLivArea        0.700927
# GarageCars       0.680625
# GarageArea       0.650888
# TotalBsmtSF      0.612134
# 1stFlrSF         0.596981
# FullBath         0.594771
# YearBuilt        0.586570
# YearRemodAdd     0.565608
# GarageYrBlt      0.541073
# TotRmsAbvGrd     0.534422
# Fireplaces       0.489449
# MasVnrArea       0.430809
# BsmtFinSF1       0.372023
# LotFrontage      0.355878
# CentralAir       0.351600
# WoodDeckSF       0.334135
# OpenPorchSF      0.321053
# 2ndFlrSF         0.319300
# HalfBath         0.313982
# LotArea          0.257320
# BsmtFullBath     0.236224
# BsmtUnfSF        0.221985
# BedroomAbvGr     0.209044
# ScreenPorch      0.121208
# PoolArea         0.069798
# Street           0.057369
# MoSold           0.057329
# 3SsnPorch        0.054900
# Utilities        0.012632
# BsmtFinSF2       0.004832
# BsmtHalfBath    -0.005149
# Id              -0.017942
# MiscVal         -0.020021
# ...

# %% [markdown]
# ## Spearman

# %%
# obtain all numeric values of df (where Pearson is defined)
df_train_numeric = df_train.select_dtypes(include='number')

# find the correlation matrix; this is a df
# then I take only the column of interest; result is Series
sale_corr = df_train_numeric.corr(method = 'spearman')['SalePrice']

# sort that series
sale_corr = sale_corr.sort_values(ascending = False)

# %%
sale_corr
# Out:
# SalePrice        1.000000
# OverallQual      0.809829
# GrLivArea        0.731310
# GarageCars       0.690711
# YearBuilt        0.652682
# GarageArea       0.649379
# FullBath         0.635957
# TotalBsmtSF      0.602725
# GarageYrBlt      0.593788
# 1stFlrSF         0.575408
# YearRemodAdd     0.571159
# TotRmsAbvGrd     0.532586
# Fireplaces       0.519247
# OpenPorchSF      0.477561
# LotArea          0.456461
# MasVnrArea       0.421309
# LotFrontage      0.409076
# WoodDeckSF       0.353802
# HalfBath         0.343008
# CentralAir       0.313286
# BsmtFinSF1       0.301871
# 2ndFlrSF         0.293598
# BedroomAbvGr     0.234907
# BsmtFullBath     0.225125
# BsmtUnfSF        0.185197
# ScreenPorch      0.100070
# MoSold           0.069432
# 3SsnPorch        0.065440
# PoolArea         0.058453
# Street           0.045814
# Utilities        0.016710
# MSSubClass       0.007192
# BsmtHalfBath    -0.012189
# Id              -0.018546
# YrSold          -0.029899
# ...

# %% [markdown]
# ## Time Based Features

# %%
sns.lineplot(data = df_train, x = 'MoSold', y= 'LogSalePrice')
# Out:
# <Axes: xlabel='MoSold', ylabel='LogSalePrice'>

# %%
sns.lineplot(data = df_train, x = 'YrSold', y= 'LogSalePrice')
# Out:
# <Axes: xlabel='YrSold', ylabel='LogSalePrice'>
